# %%
from scipy.interpolate import interp1d
import pandas as pd 
import plotly.express as px
import numpy as np

# %%
df=pd.read_csv(r"/content/drive/MyDrive/Untitled folder/covid-19.csv")
list1=df.cases.values.tolist()
df.head()
# Out:
#   Province/State Country/Region       Lat       Long    cases
# 0    Afghanistan    Afghanistan  33.93911  67.709953  47716.0
# 1        Albania        Albania  41.15330  20.168300  44436.0
# 2        Algeria        Algeria  28.03390   1.659600  89416.0
# 3        Andorra        Andorra  42.50630   1.521800   7127.0
# 4         Angola         Angola -11.20270  17.873900  15729.0

# %%
m=interp1d([1,max(list1)],[5,18])
circle_radius =m(list1)
typelist=['open-street-map','white-bg','carto-positron','carto-darkmatter','stamen-terrain','stamen-watercolor']
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/interpolate/interpolate.py:687: RuntimeWarning:
#
# invalid value encountered in less
#
# /usr/local/lib/python3.6/dist-packages/scipy/interpolate/interpolate.py:688: RuntimeWarning:
#
# invalid value encountered in greater

# %%
print('open-street-map')
fig=px.density_mapbox(df,lat='Lat',lon='Long',radius=20,zoom=2,mapbox_style='open-street-map')
fig.show()
# Out:
# open-street-map
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="78c04695-6b75-4fe6-afa8-0fa3302a2551" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("78c04695-6b75-4fe6-afa8-0fa3302a2551")) {
#                     Plotly.newPlot(
#                         '78c04695-6b75-4fe6-afa8-0fa3302a2551',
# ...

# %%
print('white-bg')
fig=px.density_mapbox(df,lat='Lat',lon='Long',radius=20,zoom=2,mapbox_style='white-bg')
fig.show()
# Out:
# white-bg
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d4f7780c-df4d-448f-a061-69542fd7d89d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d4f7780c-df4d-448f-a061-69542fd7d89d")) {
#                     Plotly.newPlot(
#                         'd4f7780c-df4d-448f-a061-69542fd7d89d',
# ...

# %%
print('carto-positron')
fig=px.density_mapbox(df,lat='Lat',lon='Long',radius=20,zoom=2,mapbox_style='carto-positron')
fig.show()
# Out:
# carto-positron
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9d372347-e2ad-4370-b3b3-d5da915776cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9d372347-e2ad-4370-b3b3-d5da915776cd")) {
#                     Plotly.newPlot(
#                         '9d372347-e2ad-4370-b3b3-d5da915776cd',
# ...

# %%
print('carto-darkmatter')
fig=px.density_mapbox(df,lat='Lat',lon='Long',radius=20,zoom=2,mapbox_style='carto-darkmatter')
fig.show()
# Out:
# carto-darkmatter
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e575908c-67f3-4a0e-bfcc-91c3ea68bc9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e575908c-67f3-4a0e-bfcc-91c3ea68bc9c")) {
#                     Plotly.newPlot(
#                         'e575908c-67f3-4a0e-bfcc-91c3ea68bc9c',
# ...

# %%
print('stamen-terrain')
fig=px.density_mapbox(df,lat='Lat',lon='Long',radius=20,zoom=2,mapbox_style='stamen-terrain')
fig.show()
# Out:
# stamen-terrain
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3a5acb8a-e13d-4993-b174-69e300c4c36b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3a5acb8a-e13d-4993-b174-69e300c4c36b")) {
#                     Plotly.newPlot(
#                         '3a5acb8a-e13d-4993-b174-69e300c4c36b',
# ...

# %%
print('stamen-watercolor')
fig=px.density_mapbox(df,lat='Lat',lon='Long',radius=20,zoom=2,mapbox_style='stamen-watercolor')
fig.show()
# Out:
# stamen-watercolor
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9e3c9905-1009-477f-be97-ed92ac4cbb13" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9e3c9905-1009-477f-be97-ed92ac4cbb13")) {
#                     Plotly.newPlot(
#                         '9e3c9905-1009-477f-be97-ed92ac4cbb13',
# ...
